# %%
import pickle
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import math

# %%
pathToFile = '/mnt/home/jbielecki1/NEMA/'
fileName = 'NEMA_IQ_384str_N0_1000_COINCIDENCES_PREPARED_part00'

data = pickle.load(open(pathToFile + fileName, 'rb'))

# %%
def dataFrameNames():
    return [
        "x1",     # 1 gamma detected x position [cm]
        "y1",     # 1 gamma detected y position [cm]
        "z1",     # 1 gamma detected z position [cm]
        "t1",     # 1 gamma detection time [ps]
        "x2",     # 2 gamma detected x position [cm]
        "y2",     # 2 gamma detected y position [cm]
        "z2",     # 2 gamma detected z position [cm]
        "t2",     # 2 gamma detection time [ps]
        "vol1",   # 1 gamma volume ID
        "vol2",   # 2 gamma volume ID
        "e1",     # 1 gamma energy loss during detection [keV]
        "e2",     # 2 gamma energy loss during detection [keV]
        "class",  # Type of coincidence(1-true, 2-phantom-scattered, 3-detector-scattered, 4-accidental)
        "sX1",    # 1 gamma emission x position [cm]
        "sY1",    # 1 gamma emission y position [cm]
        "sZ1"     # 1 gamma emission z position [cm]
        "dt",     # Detection times difference
        "rX1",    # Reconstruction point - X cord
        "rY1",    # Reconstruction point - Y cord
        "rZ1",    # Reconstruction point - Z cord
        "rError", # Difference beetwen source point and recontructed point
        "volD",   # Volumes indexes difference
        "lorL",   # LOR length
        "deg3D",  # Angle beetwen lines (in XYZ geometry) connecting detection points with the center of detector
        "deg2D",  # Angle beetwen lines (in XY geometry) connecting detection points with the center of detector
        "rL",     # Distance beetween reconstructed point and the center of detector
        "eSum"    # Sum of the detecions energies
    ]

# %%
dataClass1 = data[data['class'] == 1]
dataClass2 = data[data['class'] == 2]
dataClass3 = data[data['class'] == 3]
dataClass4 = data[data['class'] == 4]

# %%
def plotStats(subtitle, xlabel, attribute):
    plt.clf()
    fig = plt.gcf()
    plt.rc('font', size = 15)
    fig.set_size_inches(15.5, 4.5)
    fig.suptitle(subtitle, fontsize=16)
    ax1 = plt.subplot(1,3,1)
    ax1.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
    ax1.hist(dataClass1[attribute], bins = 100, alpha = 0.5, color = 'green', label = 'TRUE')
    ax1.hist(dataClass2[attribute], bins = 100, alpha = 0.5, color = 'red', label = 'PH_SCAT')
    ax1.set_xlabel(xlabel, fontsize = 20)
    ax1.set_ylabel('Liczba koincydencji', fontsize = 20)
    ax1.tick_params(direction='out', labelsize = 15)
    ax1.legend()
    ax2 = plt.subplot(1,3,2)
    ax2.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
    ax2.hist(dataClass1[attribute], bins = 100, alpha = 0.5, color = 'green', label = 'TRUE')
    ax2.hist(dataClass3[attribute], bins = 100, alpha = 0.5, color = 'red', label = 'DET_SCAT')
    ax2.set_xlabel(xlabel, fontsize = 20)
    ax2.legend()
    ax2.tick_params(direction='out', labelsize = 15)
    ax3 = plt.subplot(1,3,3)
    ax3.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
    ax3.hist(dataClass1[attribute], bins = 100, alpha = 0.5, color = 'green', label = 'TRUE')
    ax3.hist(dataClass4[attribute], bins = 100, alpha = 0.5, color = 'red', label = 'RNDM')
    ax3.set_xlabel(xlabel, fontsize = 20)
    ax3.legend()
    ax3.tick_params(direction='out', labelsize = 15)
    plt.show()

# %%
plotStats(
    subtitle = 'Energia detekcji pierwszego fotonu', 
    xlabel = 'Energia [keV]', 
    attribute = 'e1'
)

# %%
plotStats(
    subtitle = 'Współrzędna X pozycji detekcji pierwszego fotonu', 
    xlabel = 'x [cm]', 
    attribute = 'x1'
)

# %%
plotStats(
    subtitle = 'Współrzędna Z pozycji detekcji pierwszego fotonu', 
    xlabel = 'z [cm]', 
    attribute = 'z1'
)

# %%
plotStats(
    subtitle = 'Suma energii fotonów z danej koincydencji', 
    xlabel = 'Energia [keV]', 
    attribute = 'eSum'
)

# %%
plotStats(
    subtitle = 'Współrzędna X rekonstruowanego punktu', 
    xlabel = '$x_{rec}$', 
    attribute = 'eSum'
)

# %%
fig = plt.gcf()
fig.set_size_inches(15.5, 4.5)
fig.suptitle('Pozycja rekonstruowanego punktu na osi X', fontsize=16)
ax1 = plt.subplot(1,3,1)
ax1.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax1.hist(dataClass1['rX1'], bins = 100, alpha = 0.5, color = 'green', label = 'Class 1')
ax1.hist(dataClass2['rX1'], bins = 100, alpha = 0.5, color = 'red', label = 'Class 2')
ax1.set_xlabel('x - reconstrucred [cm]', fontsize = 20)
ax1.tick_params(direction='out', labelsize = 15)
ax1.legend()
ax2 = plt.subplot(1,3,2)
ax2.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax2.hist(dataClass1['rX1'], bins = 100, alpha = 0.5, color = 'green', label = 'Class 1')
ax2.hist(dataClass3['rX1'], bins = 100, alpha = 0.5, color = 'red', label = 'Class 3')
ax2.set_xlabel('x - reconstrucred [cm]', fontsize = 20)
ax2.legend()
ax2.tick_params(direction='out', labelsize = 15)
ax3 = plt.subplot(1,3,3)
ax3.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax3.hist(dataClass1['rX1'], bins = 100, alpha = 0.5, color = 'green', label = 'Class 1')
ax3.hist(dataClass4['rX1'], bins = 100, alpha = 0.5, color = 'red', label = 'Class 4')
ax3.set_xlabel('x - reconstrucred [cm]', fontsize = 20)
ax3.legend()
ax3.tick_params(direction='out', labelsize = 15)
ax3.set_yscale('log')
ax3.set_xscale('log')
plt.show()

# %%
fig = plt.gcf()
fig.set_size_inches(15.5, 4.5)
fig.suptitle('Pozycja rekonstruowanego punktu na osi Z', fontsize=16)
ax1 = plt.subplot(1,3,1)
ax1.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax1.hist(dataClass1['rZ1'], bins = 100, alpha = 0.5, color = 'green', label = 'Class 1')
ax1.hist(dataClass2['rZ1'], bins = 100, alpha = 0.5, color = 'red', label = 'Class 2')
ax1.set_xlabel('z - reconstrucred [cm]', fontsize = 20)
ax1.tick_params(direction='out', labelsize = 15)
ax1.legend()
ax2 = plt.subplot(1,3,2)
ax2.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax2.hist(dataClass1['rZ1'], bins = 100, alpha = 0.5, color = 'green', label = 'Class 1')
ax2.hist(dataClass3['rZ1'], bins = 100, alpha = 0.5, color = 'red', label = 'Class 3')
ax2.set_xlabel('z - reconstrucred [cm]', fontsize = 20)
ax2.legend()
ax2.tick_params(direction='out', labelsize = 15)
ax3 = plt.subplot(1,3,3)
ax3.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax3.hist(dataClass1['rZ1'], bins = 100, alpha = 0.5, color = 'green', label = 'Class 1')
ax3.hist(dataClass4['rZ1'], bins = 100, alpha = 0.5, color = 'red', label = 'Class 4')
ax3.set_xlabel('z - reconstrucred [cm]', fontsize = 20)
ax3.legend()
ax3.tick_params(direction='out', labelsize = 15)
ax3.set_yscale('log')
ax3.set_xscale('log')
plt.show()

# %%
fig = plt.gcf()
fig.set_size_inches(15.5, 4.5)
fig.suptitle('Długość lini LOR', fontsize=16)
ax1 = plt.subplot(1,3,1)
ax1.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax1.hist(dataClass1['lorL'], bins = 100, alpha = 0.5, color = 'green', label = 'Class 1')
ax1.hist(dataClass2['lorL'], bins = 100, alpha = 0.5, color = 'red', label = 'Class 2')
ax1.set_xlabel('LOR length [cm]', fontsize = 20)
ax1.tick_params(direction='out', labelsize = 15)
ax1.legend()
ax2 = plt.subplot(1,3,2)
ax2.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax2.hist(dataClass1['lorL'], bins = 100, alpha = 0.5, color = 'green', label = 'Class 1')
ax2.hist(dataClass3['lorL'], bins = 100, alpha = 0.5, color = 'red', label = 'Class 3')
ax2.set_xlabel('LOR length [cm]', fontsize = 20)
ax2.legend()
ax2.tick_params(direction='out', labelsize = 15)
ax3 = plt.subplot(1,3,3)
ax3.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax3.hist(dataClass1['lorL'], bins = 100, alpha = 0.5, color = 'green', label = 'Class 1')
ax3.hist(dataClass4['lorL'], bins = 100, alpha = 0.5, color = 'red', label = 'Class 4')
ax3.set_xlabel('LOR length [cm]', fontsize = 20)
ax3.legend()
ax3.tick_params(direction='out', labelsize = 15)
plt.show()

# %%
fig = plt.gcf()
fig.set_size_inches(15.5, 4.5)
fig.suptitle('Kąt pomiędzy prostymi łączącymi punkty detekcji ze środkiem detektora (w płaszczyźnie XYZ)', fontsize=16)
ax1 = plt.subplot(1,3,1)
ax1.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax1.hist(dataClass1['deg3D'], bins = 100, alpha = 0.5, color = 'green', label = 'Class 1')
ax1.hist(dataClass2['deg3D'], bins = 100, alpha = 0.5, color = 'red', label = 'Class 2')
ax1.set_xlabel(r'$\alpha\,[^\circ]$', fontsize = 20)
ax1.tick_params(direction='out', labelsize = 15)
ax1.legend()
ax2 = plt.subplot(1,3,2)
ax2.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax2.hist(dataClass1['deg3D'], bins = 100, alpha = 0.5, color = 'green', label = 'Class 1')
ax2.hist(dataClass3['deg3D'], bins = 100, alpha = 0.5, color = 'red', label = 'Class 3')
ax2.legend()
ax2.set_xlabel(r'$\alpha\,[^\circ]$', fontsize = 20)
ax2.tick_params(direction='out', labelsize = 15)
ax3 = plt.subplot(1,3,3)
ax3.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax3.hist(dataClass1['deg3D'], bins = 100, alpha = 0.5, color = 'green', label = 'Class 1')
ax3.hist(dataClass4['deg3D'], bins = 100, alpha = 0.5, color = 'red', label = 'Class 4')
ax3.legend()
ax3.set_xlabel(r'$\alpha\,[^\circ]$', fontsize = 20)
ax3.tick_params(direction='out', labelsize = 15)
plt.show()

# %%
fig = plt.gcf()
fig.set_size_inches(15.5, 4.5)
fig.suptitle('Kąt pomiędzy prostymi łączącymi punkty detekcji ze środkiem detektora (w płaszczyźnie XY)', fontsize=16)
ax1 = plt.subplot(1,3,1)
ax1.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax1.hist(dataClass1['deg2D'], bins = 100, alpha = 0.5, color = 'green', label = 'Class 1')
ax1.hist(dataClass2['deg2D'], bins = 100, alpha = 0.5, color = 'red', label = 'Class 2')
ax1.set_xlabel(r'$\alpha\,[^\circ]$', fontsize = 20)
ax1.tick_params(direction='out', labelsize = 15)
ax1.legend()
ax2 = plt.subplot(1,3,2)
ax2.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax2.hist(dataClass1['deg2D'], bins = 100, alpha = 0.5, color = 'green', label = 'Class 1')
ax2.hist(dataClass3['deg2D'], bins = 100, alpha = 0.5, color = 'red', label = 'Class 3')
ax2.legend()
ax2.set_xlabel(r'$\alpha\,[^\circ]$', fontsize = 20)
ax2.tick_params(direction='out', labelsize = 15)
ax3 = plt.subplot(1,3,3)
ax3.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax3.hist(dataClass1['deg2D'], bins = 100, alpha = 0.5, color = 'green', label = 'Class 1')
ax3.hist(dataClass4['deg2D'], bins = 100, alpha = 0.5, color = 'red', label = 'Class 4')
ax3.legend()
ax3.set_xlabel(r'$\alpha\,[^\circ]$', fontsize = 20)
ax3.tick_params(direction='out', labelsize = 15)
plt.show()

# %%
fig = plt.gcf()
fig.set_size_inches(15.5, 4.5)
fig.suptitle('Odległość rekonstruowanego punktu od środka detektora', fontsize=16)
ax1 = plt.subplot(1,3,1)
ax1.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax1.hist(dataClass1['rL'], bins = 100, alpha = 0.5, color = 'green', label = 'Class 1')
ax1.hist(dataClass2['rL'], bins = 100, alpha = 0.5, color = 'red', label = 'Class 2')
ax1.set_xlabel('distance [cm]', fontsize = 20)
ax1.tick_params(direction='out', labelsize = 15)
ax1.legend()
ax2 = plt.subplot(1,3,2)
ax2.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax2.hist(dataClass1['rL'], bins = 100, alpha = 0.5, color = 'green', label = 'Class 1')
ax2.hist(dataClass3['rL'], bins = 100, alpha = 0.5, color = 'red', label = 'Class 3')
ax2.legend()
ax2.set_xlabel('distance [cm]', fontsize = 20)
ax2.tick_params(direction='out', labelsize = 15)
ax3 = plt.subplot(1,3,3)
ax3.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
ax3.hist(dataClass1['rL'], bins = 100, alpha = 0.5, color = 'green', label = 'Class 1')
ax3.hist(dataClass4['rL'], bins = 100, alpha = 0.5, color = 'red', label = 'Class 4')
ax3.legend()
ax3.set_xlabel('distance [cm]', fontsize = 20)
ax3.tick_params(direction='out', labelsize = 15)
ax3.set_yscale('log')
ax3.set_xscale('log')
plt.show()

# %%
fig = plt.gcf()
fig.set_size_inches(18.5, 5.5)
fig.suptitle('Kąt pomiędzy prostymi łączącymi punkty detekcji ze środkiem detektora (w płaszczyźnie XY) \
w funkcji różnicy czasu', fontsize=16)
ax1 = plt.subplot(1,3,1)
ax1.hist2d(y = dataClass1['deg2D'], x = dataClass1['dt'], bins = 100)
ax1.set_ylim([100, 180])
ax1.set_xlim([-1200, 1200])
ax1.set_xlabel('dt [s]', fontsize = 20)
ax1.tick_params(direction='out', labelsize = 15)
ax1.set_title('Class 1', fontsize = 20)
ax1.set_ylabel(r'$\alpha\,[^\circ]$', fontsize = 20)
ax1.set_xlabel('dt [s]', fontsize = 20)
ax2 = plt.subplot(1,3,2)
ax2.hist2d(y = dataClass2['deg2D'], x = dataClass2['dt'], bins = 100)
ax2.set_ylim([100, 180])
ax2.set_xlim([-1200, 1200])
ax2.set_xlabel('dt [s]', fontsize = 20)
ax2.tick_params(direction='out', labelsize = 15)
ax2.set_title('Class 2', fontsize = 20)
ax2.set_ylabel(r'$\alpha\,[^\circ]$', fontsize = 20)
ax2.set_xlabel('dt [s]', fontsize = 20)
ax3 = plt.subplot(1,3,3)
ax3.hist2d(y = dataClass3['deg2D'], x = dataClass3['dt'], bins = 100)
ax3.set_ylim([100, 180])
ax3.set_xlim([-1200, 1200])
ax3.set_xlabel('dt [s]', fontsize = 20)
ax3.tick_params(direction='out', labelsize = 15)
ax3.set_title('Class 3', fontsize = 20)
ax3.set_ylabel(r'$\alpha\,[^\circ]$', fontsize = 20)
ax3.set_xlabel('dt [s]', fontsize = 20)
plt.show()

# %%
plt.clf()
fig = plt.gcf()
fig.set_size_inches(18.5, 5.5)
fig.suptitle('Odpowiednik kątowy różnicy numerów scyntylatorów w funkcji różnicy czasu', fontsize=16)
ax1 = plt.subplot(1,3,1)
ax1.hist2d(y = dataClass1['volD'], x = dataClass1['dt'], bins = 75)
ax1.set_ylim([100, 192])
ax1.set_title('Class 1', fontsize = 20)
ax1.set_ylabel('Volume difference', fontsize = 20)
ax1.set_xlabel('dt [s]', fontsize = 20)
ax2 = plt.subplot(1,3,2)
ax2.hist2d(y = dataClass2['volD'], x = dataClass2['dt'], bins = 84)
ax2.set_ylim([100, 192])
ax2.set_title('Class 2', fontsize = 20)
ax2.set_ylabel('Volume difference', fontsize = 20)
ax2.set_xlabel('dt [s]', fontsize = 20)
ax3 = plt.subplot(1,3,3)
ax3.hist2d(y = dataClass3['volD'], x = dataClass3['dt'], bins = 95)
ax3.set_ylim([100, 192])
ax3.set_title('Class 3', fontsize = 20)
ax3.set_ylabel('Volume difference', fontsize = 20)
ax3.set_xlabel('dt [s]', fontsize = 20)
plt.show()

# %%
plt.clf()
fig = plt.gcf()
fig.set_size_inches(18.5, 5.5)
fig.suptitle('Odpowiednik kątowy różnicy numerów scyntylatorów w funkcji kąta', fontsize=16)
ax1 = plt.subplot(1,3,1)
ax1.hist2d(y = dataClass1['volD'], x = dataClass1['deg2D'], bins = 75)
ax1.set_xlim([80, 180])
ax1.set_ylim([80, 200])
ax1.set_title('Class 1', fontsize = 20)
ax1.set_ylabel('Volume difference', fontsize = 20)
ax1.set_xlabel(r'$\alpha\,[^\circ]$', fontsize = 20)
ax2 = plt.subplot(1,3,2)
ax2.hist2d(y = dataClass2['volD'], x = dataClass2['deg2D'], bins = 84)
ax2.set_xlim([80, 180])
ax2.set_ylim([80, 200])
ax2.set_title('Class 2', fontsize = 20)
ax2.set_ylabel('Volume difference', fontsize = 20)
ax2.set_xlabel(r'$\alpha\,[^\circ]$', fontsize = 20)
ax3 = plt.subplot(1,3,3)
ax3.hist2d(y = dataClass3['volD'], x = dataClass3['deg2D'], bins = 95)
ax3.set_xlim([80, 180])
ax3.set_ylim([80, 200])
ax3.set_title('Class 3', fontsize = 20)
ax3.set_ylabel('Volume difference', fontsize = 20)
ax3.set_xlabel(r'$\alpha\,[^\circ]$', fontsize = 20)
plt.show()
